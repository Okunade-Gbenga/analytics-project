# %%
import pandas as pd  ### for dataframes and data cleaning
import re
import numpy as np
import pyodbc ### for the sql connections
import getpass ### to input db password so no one else knows it 
import datetime as dt ### fro dates cleaning
import warnings
import sqlalchemy 
from sqlalchemy import
# Out:
#   File "<ipython-input-37-947bc3f40b5b>", line 9
#     from sqlalchemy import
#                           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
Customer = pd.read_excel('Study_Data.xlsx', sheet_name = 0)

# %%
print(Customer)
# Out:
#           id                   userid                      firstname  \
# 0          1      PIV7132019122352PM1                       Nnadozie
# 1          2      PIV7132019122351PM2                     Oluwatoyin
# 2          3      PIV7132019122351PM3                          jimoh
# 3          4      PIV7132019122352PM4                      Emmanuel
# 4          5      PIV7132019122352PM5  Isaac
# ...      ...                      ...                            ...
# 40158  40275   PIV824202240634PM40275                          Peter
# 40159  40276   PIV824202263837PM40276                 samuel majesty
# 40160  40277  PIV8242022100445PM40277                           Abba
# 40161  40278  PIV8242022113408PM40278                         Sikiru
# 40162  40279   PIV825202291339AM40279                          Uduak
#
#                   BANKNAME             status MARITAL_STATUS      gender  \
# 0              Access Bank  Stage 2 Completed     Single      Male
# ...

# %%
Customer.head(10)
# Out:
#    id                userid                      firstname  \
# 0   1   PIV7132019122352PM1                       Nnadozie
# 1   2   PIV7132019122351PM2                     Oluwatoyin
# 2   3   PIV7132019122351PM3                          jimoh
# 3   4   PIV7132019122352PM4                      Emmanuel
# 4   5   PIV7132019122352PM5  Isaac
# 5   6   PIV7132019122352PM6                           Abba
# 6   7   PIV7132019122352PM7                       Suleiman
# 7   8   PIV7132019122352PM8                           Umar
# 8   9   PIV7132019122352PM9                         Yakubu
# 9  10  PIV7132019122352PM10                          Naomi
#
#               BANKNAME             status MARITAL_STATUS      gender  \
# 0          Access Bank  Stage 2 Completed     Single      Male
# 1            Skye Bank  Stage 1 Completed     Single      Female
# 2                  NaN  Stage 1 Completed            NaN         NaN
# 3       First Bank PLC  Stage 1 Completed     Single      Male
# ...

# %%
print(Customer.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40163 entries, 0 to 40162
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                40163 non-null  int64
#  1   userid            40163 non-null  object
#  2   firstname         40163 non-null  object
#  3   BANKNAME          17176 non-null  object
#  4   status            40163 non-null  object
#  5   MARITAL_STATUS    7429 non-null   object
#  6   gender            17441 non-null  object
#  7   dob               17433 non-null  object
#  8   ISKYCAPPROVED     40163 non-null  int64
#  9   KYC_STATUS        40163 non-null  object
#  10  REC_CRE_DATE      40163 non-null  datetime64[ns]
#  11  rec_cre_source    40163 non-null  object
#  12  LAST_UPDATE_DATE  9448 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(2), object(9)
# memory usage: 2.6+ MB
# None

# %%
Customer.tail()
# Out:
#           id                   userid       firstname BANKNAME  \
# 40158  40275   PIV824202240634PM40275           Peter      NaN
# 40159  40276   PIV824202263837PM40276  samuel majesty      NaN
# 40160  40277  PIV8242022100445PM40277            Abba      NaN
# 40161  40278  PIV8242022113408PM40278          Sikiru      NaN
# 40162  40279   PIV825202291339AM40279           Uduak      NaN
#
#                   status MARITAL_STATUS gender  dob  ISKYCAPPROVED  \
# 40158  Stage 1 Completed            NaN    NaN  NaN              0
# 40159  Stage 1 Completed            NaN    NaN  NaN              0
# 40160  Stage 1 Completed            NaN    NaN  NaN              0
# 40161  Stage 1 Completed            NaN    NaN  NaN              0
# 40162  Stage 1 Completed            NaN    NaN  NaN              0
#
#            KYC_STATUS            REC_CRE_DATE rec_cre_source LAST_UPDATE_DATE
# 40158  NO KYC Details 2022-08-24 16:06:34.310     Web                     NaT
# ...

# %%
Customer["BANKNAME"].fillna("NoBankInfo", inplace = True)
Customer["MARITAL_STATUS"].fillna("Unknown", inplace = True)
Customer["gender"].fillna("Unknown", inplace = True)
Customer["dob"].fillna("1900-01-01", inplace = True)
Customer["LAST_UPDATE_DATE"].fillna("1900-01-01", inplace = True)

Customer.tail(10)
# Out:
#           id                   userid       firstname                BANKNAME  \
# 40153  40270  PIV8222022112941PM40270          Moses   United Bank for Africa
# 40154  40271  PIV8232022110405AM40271           Wasiu              NoBankInfo
# 40155  40272  PIV8232022124608PM40272       Yangilli               NoBankInfo
# 40156  40273   PIV823202221445PM40273         Victor               NoBankInfo
# 40157  40274   PIV824202222109PM40274      Abdulbasit              NoBankInfo
# 40158  40275   PIV824202240634PM40275           Peter              NoBankInfo
# 40159  40276   PIV824202263837PM40276  samuel majesty              NoBankInfo
# 40160  40277  PIV8242022100445PM40277            Abba              NoBankInfo
# 40161  40278  PIV8242022113408PM40278          Sikiru              NoBankInfo
# 40162  40279   PIV825202291339AM40279           Uduak              NoBankInfo
#
#                   status MARITAL_STATUS      gender                  dob  \
# ...

# %%
Customer["dob"] = pd.to_datetime(Customer["dob"], errors = "coerce")
Customer.tail()
# Out:
#           id                   userid       firstname    BANKNAME  \
# 40158  40275   PIV824202240634PM40275           Peter  NoBankInfo
# 40159  40276   PIV824202263837PM40276  samuel majesty  NoBankInfo
# 40160  40277  PIV8242022100445PM40277            Abba  NoBankInfo
# 40161  40278  PIV8242022113408PM40278          Sikiru  NoBankInfo
# 40162  40279   PIV825202291339AM40279           Uduak  NoBankInfo
#
#                   status MARITAL_STATUS   gender        dob  ISKYCAPPROVED  \
# 40158  Stage 1 Completed        Unknown  Unknown 1900-01-01              0
# 40159  Stage 1 Completed        Unknown  Unknown 1900-01-01              0
# 40160  Stage 1 Completed        Unknown  Unknown 1900-01-01              0
# 40161  Stage 1 Completed        Unknown  Unknown 1900-01-01              0
# 40162  Stage 1 Completed        Unknown  Unknown 1900-01-01              0
#
#            KYC_STATUS            REC_CRE_DATE rec_cre_source LAST_UPDATE_DATE
# ...

# %%
print(Customer.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40163 entries, 0 to 40162
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                40163 non-null  int64
#  1   userid            40163 non-null  object
#  2   firstname         40163 non-null  object
#  3   BANKNAME          40163 non-null  object
#  4   status            40163 non-null  object
#  5   MARITAL_STATUS    40163 non-null  object
#  6   gender            40163 non-null  object
#  7   dob               40152 non-null  datetime64[ns]
#  8   ISKYCAPPROVED     40163 non-null  int64
#  9   KYC_STATUS        40163 non-null  object
#  10  REC_CRE_DATE      40163 non-null  datetime64[ns]
#  11  rec_cre_source    40163 non-null  object
#  12  LAST_UPDATE_DATE  40163 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(9)
# memory usage: 2.6+ MB
# None

# %%
Customer.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40158    False
# 40159    False
# 40160    False
# 40161    False
# 40162    False
# Length: 40163, dtype: bool

# %%
Customer.drop_duplicates(inplace = True)

# %%
print(Customer.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40163 entries, 0 to 40162
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                40163 non-null  int64
#  1   userid            40163 non-null  object
#  2   firstname         40163 non-null  object
#  3   BANKNAME          40163 non-null  object
#  4   status            40163 non-null  object
#  5   MARITAL_STATUS    40163 non-null  object
#  6   gender            40163 non-null  object
#  7   dob               40152 non-null  datetime64[ns]
#  8   ISKYCAPPROVED     40163 non-null  int64
#  9   KYC_STATUS        40163 non-null  object
#  10  REC_CRE_DATE      40163 non-null  datetime64[ns]
#  11  rec_cre_source    40163 non-null  object
#  12  LAST_UPDATE_DATE  40163 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(9)
# memory usage: 2.9+ MB
# None

# %%
import pandas as pd  ### for dataframes and data cleaning
import re
import numpy as np
import pyodbc ### for the sql connections
import getpass ### to input db password so no one else knows it 
import datetime as dt ### fro dates cleaning
import warnings
import sqlalchemy 
from sqlalchemy import
# Out:
#   File "<ipython-input-57-947bc3f40b5b>", line 9
#     from sqlalchemy import
#                           ^
# SyntaxError: invalid syntax

# %%
import warnings
import datetime as dt
import pyodbc
import sqlalchemy 
from sqlalchemy import create_engine
warnings.filterwarnings('ignore')

# %%
conn_new = pyodbc.connect("Driver={SQL Server Native Client 11.0};"
                      "Server=DESKTOP-ARC6CSA\GBENGAPC;"
                      "Database=GEEYDB;"
                      "uid=sa;"
                      "pwd=#Ayodeji11;"
                      )

cursor = conn_new.cursor()

# %%
cursor.execute('''
                CREATE TABLE mtn_ussd_log (
                Request_Response nvarchar(20),
                Status nvarchar(20),
                Status_Message nvarchar(200),
                Request nvarchar(200),
                Date Datetime,
                Time nvarchar(30)
              )
               ''')

conn_new.commit()

# %%
data_insert =  (""" INSERT INTO mtn_ussd_log (Request_Response,Status, Status_Message,Request,Date, Time) VALUES(?,?,?,?,?,?) """)

# %%
start_time = dt.datetime.now()

for i, row in data_final_main.iterrows():
    curs.execute(data_insert, list(row))
    engine.commit()
    
end_time = dt.datetime.now()
print(f'Time elaspsed (hh:mm:ss:ms): {end_time - start_time}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-5907620ec3e3> in <module>
#       1 start_time = dt.datetime.now()
#       2
# ----> 3 for i, row in data_final_main.iterrows():
#       4     curs.execute(data_insert, list(row))
#       5     engine.commit()
#
# NameError: name 'data_final_main' is not defined

# %%
import urllib
connection_string = 'mssql+pyodbc://sa:%s@DESKTOP-ARC6CSA\GBENGAPC/GEEYDB?driver=SQL Server' % urllib.parse.quote_plus("#Ayodeji11")

# %%
import sqlalchemy as sa
cnx = sa.create_engine(connection_string)

# %%
Customer
# Out:
#           id                   userid                      firstname  \
# 0          1      PIV7132019122352PM1                       Nnadozie
# 1          2      PIV7132019122351PM2                     Oluwatoyin
# 2          3      PIV7132019122351PM3                          jimoh
# 3          4      PIV7132019122352PM4                      Emmanuel
# 4          5      PIV7132019122352PM5  Isaac
# ...      ...                      ...                            ...
# 40158  40275   PIV824202240634PM40275                          Peter
# 40159  40276   PIV824202263837PM40276                 samuel majesty
# 40160  40277  PIV8242022100445PM40277                           Abba
# 40161  40278  PIV8242022113408PM40278                         Sikiru
# 40162  40279   PIV825202291339AM40279                          Uduak
#
#                   BANKNAME             status MARITAL_STATUS      gender  \
# 0              Access Bank  Stage 2 Completed     Single      Male
# ...

# %%
Customer.to_sql('CustomerCleanRecords', con=cnx, if_exists="append",index=False,chunksize=1000)
